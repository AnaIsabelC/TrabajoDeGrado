# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt



from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data = pd.read_csv("/content/drive/My Drive/Trabajo de Grado/Tesis/Pruebas/Multicriterio/Datasets/datos_predichosARBOL.csv")
#data = pd.read_csv("/content/drive/My Drive/Trabajo de Grado/Tesis/Pruebas/Multicriterio/Datasets/datos_simulados_equilibrados_MulticriterioARBOL.csv")
data.head(10)
# Out:
#    Promedio Temperatura  Promedio Humedad  Promedio CO2  Promedio TVCO  \
# 0              0.440205          0.168472      0.074892       0.015264
# 1              0.113952          0.180013      0.135815       0.080880
# 2              0.366971          0.165835      0.012062       0.067152
# 3              0.375294          0.131329      0.001785       0.034272
# 4              0.418682          0.071505      0.088985       0.045456
# 5              0.412423          0.160093      0.007508       0.098880
# 6              0.139181          0.072855      0.020554       0.020400
# 7              0.383324          0.151435      0.101354       0.045888
# 8              0.031479          0.229062      0.104431       0.095904
# 9              0.330314          0.059820      0.152985       0.048864
#
#        Suma Alerta predicha
# 0  0.698834        Muy Alto
# 1  0.510661            Alto
# 2  0.612020            Alto
# 3  0.542679            Alto
# 4  0.624627        Muy Alto
# 5  0.678903        Muy Alto
# 6  0.252990           Medio
# 7  0.682001        Muy Alto
# 8  0.460876            Alto
# 9  0.591983            Alto

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 6 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Promedio Temperatura  10000 non-null  float64
#  1   Promedio Humedad      10000 non-null  float64
#  2   Promedio CO2          10000 non-null  float64
#  3   Promedio TVCO         10000 non-null  float64
#  4   Suma                  10000 non-null  float64
#  5   Alerta predicha       10000 non-null  object
# dtypes: float64(5), object(1)
# memory usage: 468.9+ KB

# %%
# Variables predictoras
# X = data.iloc[:,0:5]
X = data.iloc[:,0:4]

# Variable a predecir
Y = data.iloc[:,5]

X.head()
# Out:
#    Promedio Temperatura  Promedio Humedad  Promedio CO2  Promedio TVCO
# 0              0.440205          0.168472      0.074892       0.015264
# 1              0.113952          0.180013      0.135815       0.080880
# 2              0.366971          0.165835      0.012062       0.067152
# 3              0.375294          0.131329      0.001785       0.034272
# 4              0.418682          0.071505      0.088985       0.045456

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, train_size=0.2, random_state=42)
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2000 entries, 399 to 7270
# Data columns (total 4 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Promedio Temperatura  2000 non-null   float64
#  1   Promedio Humedad      2000 non-null   float64
#  2   Promedio CO2          2000 non-null   float64
#  3   Promedio TVCO         2000 non-null   float64
# dtypes: float64(4)
# memory usage: 78.1 KB

# %%
pip install micromlgen
# Out:
# Collecting micromlgen
#   Downloading micromlgen-1.1.28.tar.gz (12 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from micromlgen) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->micromlgen) (2.1.4)
# Building wheels for collected packages: micromlgen
#   Building wheel for micromlgen (setup.py) ... done
#   Created wheel for micromlgen: filename=micromlgen-1.1.28-py3-none-any.whl size=32152 sha256=94508b961dca890b9efa14a362f9a0011895b4b1edf7aedc6ca599521818b609
#   Stored in directory: /root/.cache/pip/wheels/97/54/64/5d82c310920abe1be0d120313ceb9e12c88f5701f53f6ed248
# Successfully built micromlgen
# Installing collected packages: micromlgen
# Successfully installed micromlgen-1.1.28

# %%
from matplotlib import pyplot as plt
from sklearn.tree import plot_tree
from sklearn import tree
from sklearn.ensemble import RandomForestClassifier
from micromlgen import port

# Crear un objeto RandomForestClassifier
bosque = RandomForestClassifier(n_estimators=100, random_state=0, max_depth=5)

# Ajustar el RandomForestClassifier a los datos de entrenamiento
bosque_varroa = bosque.fit(X_train, Y_train)

# Imprimir el código C++ para microcontroladores
print(port(bosque_varroa))
# Out:
# #pragma once
# #include <cstdarg>
# namespace Eloquent {
#     namespace ML {
#         namespace Port {
#             class RandomForest {
#                 public:
#                     /**
#                     * Predict class for features vector
#                     */
#                     int predict(float *x) {
#                         uint8_t votes[4] = { 0 };
#                         // tree #1
#                         if (x[0] <= 0.363807812333107) {
#                             if (x[1] <= 0.09244535490870476) {
#                                 if (x[0] <= 0.21278852224349976) {
#                                     if (x[2] <= 0.09489230811595917) {
#                                         if (x[0] <= 0.045615335926413536) {
#                                             votes[1] += 1;
#                                         }
#
#                                         else {
#                                             votes[2] += 1;
#                                         }
#                                     }
#
#                                     else {
#                                         if (x[3] <= 0.0663600005209446) {
#                                             votes[2] += 1;
#                                         }
#
#                                         else {
#                                             votes[0] += 1;
#                                         }
#                                     }
#                                 }
#
#                                 else {
#                                     if (x[3] <= 0.04915199987590313) {
#                                         if (x[0] <= 0.27102844417095184) {
#                                             votes[2] += 1;
#                                         }
#
#                                         else {
#                                             votes[0] += 1;
#                                         }
#                                     }
#
#                                     else {
#                                         if (x[2] <= 0.158492311835289) {
#                                             votes[0] += 1;
#                                         }
#
#                                         else {
#                                             votes[3] += 1;
#                                         }
#                                     }
#                                 }
#                             }
#
#                             else {
#                                 if (x[2] <= 0.035692308098077774) {
#                                     if (x[3] <= 0.053807999938726425) {
#                                         if (x[3] <= 0.0329039990901947) {
#                                             votes[2] += 1;
#                                         }
#
#                                         else {
#                                             votes[2] += 1;
#                                         }
#                                     }
#
#                                     else {
#                                         if (x[0] <= 0.07047216966748238) {
#                                             votes[2] += 1;
#                                         }
#
#                                         else {
#                                             votes[0] += 1;
#                                         }
#                                     }
#                                 }
#
#                                 else {
#                                     if (x[0] <= 0.2692265808582306) {
#                                         if (x[3] <= 0.03863999992609024) {
#                                             votes[0] += 1;
#                                         }
#
#                                         else {
#                                             votes[0] += 1;
#                                         }
#                                     }
#
#                                     else {
#                                         if (x[1] <= 0.16447129845619202) {
#                                             votes[0] += 1;
#                                         }
#
#                                         else {
#                                             votes[3] += 1;
#                                         }
#                                     }
#                                 }
#                             }
#                         }
#
#                         else {
#                             if (x[2] <= 0.08338461443781853) {
#                                 if (x[1] <= 0.08571112155914307) {
#                                     if (x[3] <= 0.08800799772143364) {
#                                         if (x[0] <= 0.4407350867986679) {
#                                             votes[0] += 1;
#                                         }
#
#                                         else {
#                                             votes[0] += 1;
#                                         }
#                                     }
#
#                                     else {
#                                         if (x[1] <= 0.03728190250694752) {
#                                             votes[0] += 1;
#                                         }
#
#                                         else {
#                                             votes[3] += 1;
#                                         }
#                                     }
#                                 }
#
#                                 else {
#                                     if (x[3] <= 0.05095199868083) {
#                                         if (x[2] <= 0.033630769699811935) {
#                                             votes[0] += 1;
#                                         }
#
#                                         else {
#                                             votes[3] += 1;
#                                         }
#                                     }
#
#                                     else {
#                                         if (x[0] <= 0.3772462457418442) {
#                                             votes[0] += 1;
#                                         }
#
#                                         else {
#                                             votes[3] += 1;
#                                         }
#                                     }
#                                 }
#                             }
#
#                             else {
#                                 if (x[2] <= 0.12913846224546432) {
#                                     if (x[1] <= 0.04578791745007038) {
#                                         if (x[3] <= 0.0717839989811182) {
#                                             votes[0] += 1;
#                                         }
#
#                                         else {
#                                             votes[3] += 1;
#                                         }
#                                     }
#
#                                     else {
#                                         if (x[1] <= 0.08187370374798775) {
#                                             votes[3] += 1;
#                                         }
#
#                                         else {
#                                             votes[3] += 1;
#                                         }
#                                     }
#                                 }
#
#                                 else {
#                                     if (x[1] <= 0.0073714479804039) {
#                                         if (x[3] <= 0.00712800002656877) {
#                                             votes[0] += 1;
#                                         }
#
#                                         else {
#                                             votes[3] += 1;
#                                         }
#                                     }
#
#                                     else {
#                                         votes[3] += 1;
#                                     }
#                                 }
#                             }
#                         }
#
#                         // tree #2
#                         if (x[0] <= 0.26048627495765686) {
#                             if (x[0] <= 0.12263287603855133) {
#                                 if (x[2] <= 0.10498461499810219) {
#                                     if (x[1] <= 0.21072733402252197) {
#                                         if (x[1] <= 0.09529664739966393) {
#                                             votes[2] += 1;
#                                         }
#
#                                         else {
#                                             votes[2] += 1;
#                                         }
#                                     }
#
#                                     else {
#                                         if (x[3] <= 0.0614400003105402) {
#                                             votes[2] += 1;
#                                         }
#
#                                         else {
#                                             votes[0] += 1;
#                                         }
#                                     }
#                                 }
#
#                                 else {
#                                     if (x[1] <= 0.12636034935712814) {
#                                         if (x[0] <= 0.12078917399048805) {
#                                             votes[2] += 1;
#                                         }
#
#                                         else {
#                                             votes[0] += 1;
#                                         }
#                                     }
#
#                                     else {
#                                         if (x[3] <= 0.03492000140249729) {
#                                             votes[0] += 1;
#                                         }
#
#                                         else {
#                                             votes[0] += 1;
#                                         }
#                                     }
#                                 }
#                             }
#
#                             else {
#                                 if (x[2] <= 0.040584614500403404) {
#                                     if (x[0] <= 0.17354264110326767) {
#                                         if (x[3] <= 0.0024480000138282776) {
#                                             votes[1] += 1;
#                                         }
#
#                                         else {
#                                             votes[2] += 1;
#                                         }
#                                     }
#
#                                     else {
#                                         if (x[1] <= 0.09399134665727615) {
#                                             votes[2] += 1;
#                                         }
#
#                                         else {
#                                             votes[0] += 1;
#                                         }
#                                     }
#                                 }
#
#                                 else {
#                                     if (x[3] <= 0.04536000080406666) {
#                                         if (x[3] <= 0.040535999462008476) {
#                                             votes[0] += 1;
#                                         }
#
#                                         else {
#                                             votes[2] += 1;
#                                         }
#                                     }
#
#                                     else {
#                                         if (x[2] <= 0.1568923071026802) {
#                                             votes[0] += 1;
#                                         }
#
#                                         else {
#                                             votes[0] += 1;
#                                         }
#                                     }
#                                 }
#                             }
#                         }
#
#                         else {
#                             if (x[0] <= 0.3773698955774307) {
#                                 if (x[1] <= 0.17350857704877853) {
#                                     if (x[3] <= 0.10293599963188171) {
#                                         if (x[1] <= 0.1011078767478466) {
#                                             votes[0] += 1;
#                                         }
#
#                                         else {
#                                             votes[0] += 1;
#                                         }
#                                     }
#
#                                     else {
#                                         if (x[1] <= 0.08987630158662796) {
#                                             votes[0] += 1;
#                                         }
#
#                                         else {
#                                             votes[3] += 1;
#                                         }
#                                     }
#                                 }
#
#                                 else {
#                                     if (x[0] <= 0.3102787882089615) {
#                                         if (x[0] <= 0.3053703010082245) {
#                                             votes[3] += 1;
#                                         }
#
#                                         else {
#                                             votes[0] += 1;
#                                         }
#                                     }
#
#                                     else {
#                                         if (x[2] <= 0.04541538469493389) {
#                                             votes[3] += 1;
#                                         }
#
#                                         else {
#                                             votes[3] += 1;
#                                         }
#                                     }
#                                 }
#                             }
#
#                             else {
#                                 if (x[3] <= 0.044999999925494194) {
#                                     if (x[2] <= 0.11919999867677689) {
#                                         if (x[1] <= 0.10897858068346977) {
#                                             votes[0] += 1;
#                                         }
#
#                                         else {
#                                             votes[3] += 1;
#                                         }
#                                     }
#
#                                     else {
#                                         if (x[2] <= 0.1292615383863449) {
#                                             votes[3] += 1;
#                                         }
#
#                                         else {
#                                             votes[3] += 1;
#                                         }
#                                     }
#                                 }
#
#                                 else {
#                                     if (x[1] <= 0.06323759816586971) {
#                                         if (x[0] <= 0.42054300010204315) {
#                                             votes[0] += 1;
#                                         }
#
#                                         else {
#                                             votes[3] += 1;
#                                         }
#                                     }
#
#                                     else {
#                                         if (x[3] <= 0.05040000006556511) {
#                                             votes[3] += 1;
#                                         }
#
#                                         else {
#                                             votes[3] += 1;
#                                         }
#                                     }
#                                 }
#                             }
#                         }
#
#                         // tree #3
#                         if (x[0] <= 0.12263287603855133) {
#                             if (x[0] <= 0.058114225044846535) {
#                                 if (x[2] <= 0.09590769186615944) {
#                                     if (x[1] <= 0.03328734450042248) {
#                                         if (x[2] <= 0.07636922970414162) {
#                                             votes[1] += 1;
#                                         }
#
#                                         else {
#                                             votes[1] += 1;
#                                         }
#                                     }
#
#                                     else {
#                                         if (x[3] <= 0.03765599988400936) {
#                                             votes[2] += 1;
#                                         }
#
#                                         else {
#                                             votes[2] += 1;
#                                         }
#                                     }
#                                 }
#
#                                 else {
#                                     if (x[1] <= 0.2022947371006012) {
#                                         if (x[3] <= 0.09525600075721741) {
#                                             votes[2] += 1;
#                                         }
#
#                                         else {
#                                             votes[2] += 1;
#                                         }
#                                     }
#
#                                     else {
#                                         votes[0] += 1;
#                                     }
#                                 }
#                             }
#
#                             else {
#                                 if (x[1] <= 0.10010448098182678) {
#                                     if (x[1] <= 0.07925783097743988) {
#                                         if (x[2] <= 0.01504615368321538) {
#                                             votes[1] += 1;
#                                         }
#
#                                         else {
#                                             votes[2] += 1;
#                                         }
#                                     }
#
#                                     else {
#                                         if (x[2] <= 0.12680000066757202) {
#                                             votes[2] += 1;
#                                         }
#
#                                         else {
#                                             votes[0] += 1;
#                                         }
#                                     }
#                                 }
#
#                                 else {
#                                     if (x[2] <= 0.06719999760389328) {
#                                         if (x[1] <= 0.19126437604427338) {
#                                             votes[2] += 1;
#                                         }
#
#                                         else {
#                                             votes[0] += 1;
#                                         }
#                                     }
#
#                                     else {
#                                         if (x[1] <= 0.1473550871014595) {
#                                             votes[0] += 1;
#                                         }
#
#                                         else {
#                                             votes[0] += 1;
#                                         }
#                                     }
#                                 }
#                             }
#                         }
#
#                         else {
#                             if (x[0] <= 0.3342224955558777) {
#                                 if (x[1] <= 0.04426829516887665) {
#                                     if (x[0] <= 0.25266532599925995) {
#                                         if (x[0] <= 0.22402624040842056) {
#                                             votes[2] += 1;
#                                         }
#
#                                         else {
#                                             votes[0] += 1;
#                                         }
#                                     }
#
#                                     else {
#                                         if (x[2] <= 0.07129230722784996) {
#                                             votes[0] += 1;
#                                         }
#
#                                         else {
#                                             votes[0] += 1;
#                                         }
#                                     }
#                                 }
#
#                                 else {
#                                     if (x[1] <= 0.22013847529888153) {
#                                         if (x[0] <= 0.2230103313922882) {
#                                             votes[0] += 1;
#                                         }
#
#                                         else {
#                                             votes[0] += 1;
#                                         }
#                                     }
#
#                                     else {
#                                         if (x[0] <= 0.2604476809501648) {
#                                             votes[0] += 1;
#                                         }
#
#                                         else {
#                                             votes[3] += 1;
#                                         }
#                                     }
#                                 }
#                             }
#
#                             else {
#                                 if (x[2] <= 0.08366153761744499) {
#                                     if (x[1] <= 0.1430831328034401) {
#                                         if (x[1] <= 0.06945405155420303) {
#                                             votes[0] += 1;
#                                         }
#
#                                         else {
#                                             votes[0] += 1;
#                                         }
#                                     }
#
#                                     else {
#                                         if (x[3] <= 0.011376000009477139) {
#                                             votes[0] += 1;
#                                         }
#
#                                         else {
#                                             votes[3] += 1;
#                                         }
#                                     }
#                                 }
#
#                                 else {
#                                     if (x[0] <= 0.4191194176673889) {
#                                         if (x[2] <= 0.1190461553633213) {
#                                             votes[3] += 1;
#                                         }
#
#                                         else {
#                                             votes[3] += 1;
#                                         }
#                                     }
#
#                                     else {
#                                         if (x[3] <= 0.04094400070607662) {
#                                             votes[3] += 1;
#                                         }
#
#                                         else {
#                                             votes[3] += 1;
#                                         }
#                                     }
#                                 }
#                             }
#                         }
#
#                         // tree #4
#                         if (x[0] <= 0.3146772086620331) {
#                             if (x[0] <= 0.13798527419567108) {
#                                 if (x[1] <= 0.14717404544353485) {
#                                     if (x[0] <= 0.027858479879796505) {
#                                         if (x[1] <= 0.03273533098399639) {
#                                             votes[1] += 1;
#                                         }
#
#                                         else {
#                                             votes[2] += 1;
#                                         }
#                                     }
#
#                                     else {
#                                         if (x[1] <= 0.06226916424930096) {
#                                             votes[2] += 1;
#                                         }
#
#                                         else {
#                                             votes[2] += 1;
#                                         }
#                                     }
#                                 }
#
#                                 else {
#                                     if (x[0] <= 0.05791899003088474) {
#                                         if (x[3] <= 0.06839999929070473) {
#                                             votes[2] += 1;
#                                         }
#
#                                         else {
#                                             votes[0] += 1;
#                                         }
#                                     }
#
#                                     else {
#                                         if (x[3] <= 0.03854399919509888) {
#                                             votes[0] += 1;
#                                         }
#
#                                         else {
#                                             votes[0] += 1;
#                                         }
#                                     }
#                                 }
#                             }
#
#                             else {
#                                 if (x[0] <= 0.22464569658041) {
#                                     if (x[1] <= 0.051150210201740265) {
#                                         if (x[3] <= 0.11087999865412712) {
#                                             votes[2] += 1;
#                                         }
#
#                                         else {
#                                             votes[0] += 1;
#                                         }
#                                     }
#
#                                     else {
#                                         if (x[2] <= 0.08181538432836533) {
#                                             votes[0] += 1;
#                                         }
#
#                                         else {
#                                             votes[0] += 1;
#                                         }
#                                     }
#                                 }
#
#                                 else {
#                                     if (x[3] <= 0.11923199892044067) {
#                                         if (x[1] <= 0.14709938317537308) {
#                                             votes[0] += 1;
#                                         }
#
#                                         else {
#                                             votes[0] += 1;
#                                         }
#                                     }
#
#                                     else {
#                                         votes[3] += 1;
#                                     }
#                                 }
#                             }
#                         }
#
#                         else {
#                             if (x[1] <= 0.08534545451402664) {
#                                 if (x[3] <= 0.08229599893093109) {
#                                     if (x[2] <= 0.12021538615226746) {
#                                         if (x[0] <= 0.46237944066524506) {
#                                             votes[0] += 1;
#                                         }
#
#                                         else {
#                                             votes[3] += 1;
#                                         }
#                                     }
#
#                                     else {
#                                         if (x[0] <= 0.3946859687566757) {
#                                             votes[0] += 1;
#                                         }
#
#                                         else {
#                                             votes[3] += 1;
#                                         }
#                                     }
#                                 }
#
#                                 else {
#                                     if (x[1] <= 0.041705867275595665) {
#                                         if (x[0] <= 0.43630166351795197) {
#                                             votes[0] += 1;
#                                         }
#
#                                         else {
#                                             votes[3] += 1;
#                                         }
#                                     }
#
#                                     else {
#                                         if (x[1] <= 0.08111734688282013) {
#                                             votes[3] += 1;
#                                         }
#
#                                         else {
#                                             votes[0] += 1;
#                                         }
#                                     }
#                                 }
#                             }
#
#                             else {
#                                 if (x[2] <= 0.0394461527466774) {
#                                     if (x[1] <= 0.20238901674747467) {
#                                         if (x[0] <= 0.4281604439020157) {
#                                             votes[0] += 1;
#                                         }
#
#                                         else {
#                                             votes[3] += 1;
#                                         }
#                                     }
#
#                                     else {
#                                         if (x[1] <= 0.21244337409734726) {
#                                             votes[3] += 1;
#                                         }
#
#                                         else {
#                                             votes[3] += 1;
#                                         }
#                                     }
#                                 }
#
#                                 else {
#                                     if (x[0] <= 0.3568630665540695) {
#                                         if (x[3] <= 0.03611999936401844) {
#                                             votes[0] += 1;
#                                         }
#
#                                         else {
#                                             votes[3] += 1;
#                                         }
#                                     }
#
#                                     else {
#                                         if (x[0] <= 0.3708418607711792) {
#                                             votes[3] += 1;
#                                         }
#
#                                         else {
#                                             votes[3] += 1;
#                                         }
#                                     }
#                                 }
#                             }
#                         }
#
#                         // tree #5
#                         if (x[0] <= 0.27423807978630066) {
#                             if (x[0] <= 0.12305671349167824) {
#                                 if (x[1] <= 0.18121882528066635) {
#                                     if (x[2] <= 0.10769230499863625) {
#                                         if (x[3] <= 0.022055999375879765) {
#                                             votes[2] += 1;
#                                         }
#
#                                         else {
#                                             votes[2] += 1;
#                                         }
#                                     }
#
#                                     else {
#                                         if (x[3] <= 0.04391999915242195) {
#                                             votes[2] += 1;
#                                         }
#
#                                         else {
#                                             votes[0] += 1;
#                                         }
#                                     }
#                                 }
#
#                                 else {
#                                     if (x[0] <= 0.04978908598423004) {
#                                         if (x[3] <= 0.06839999929070473) {
#                                             votes[2] += 1;
#                                         }
#
#                                         else {
#                                             votes[0] += 1;
#                                         }
#                                     }
#
#                                     else {
#                                         if (x[3] <= 0.05013599991798401) {
#                                             votes[0] += 1;
#                                         }
#
#                                         else {
#                                             votes[0] += 1;
#                                         }
#                                     }
#                                 }
#                             }
#
#                             else {
#                                 if (x[1] <= 0.06756122782826424) {
#                                     if (x[2] <= 0.09452307596802711) {
#                                         if (x[1] <= 0.01853320188820362) {
#                                             votes[2] += 1;
#                                         }
#
#                                         else {
#                                             votes[2] += 1;
#                                         }
#                                     }
#
#                                     else {
#                                         if (x[3] <= 0.015072000678628683) {
#                                             votes[2] += 1;
#                                         }
#
#                                         else {
#                                             votes[0] += 1;
#                                         }
#                                     }
#                                 }
#
#                                 else {
#                                     if (x[2] <= 0.04240000061690807) {
#                                         if (x[3] <= 0.023784000426530838) {
#                                             votes[2] += 1;
#                                         }
#
#                                         else {
#                                             votes[0] += 1;
#                                         }
#                                     }
#
#                                     else {
#                                         if (x[1] <= 0.22637425363063812) {
#                                             votes[0] += 1;
#                                         }
#
#                                         else {
#                                             votes[0] += 1;
#                                         }
#                                     }
#                                 }
#                             }
#                         }
#
#                         else {
#                             if (x[2] <= 0.08366153761744499) {
#                                 if (x[1] <= 0.15302474051713943) {
#                                     if (x[0] <= 0.42820148169994354) {
#                                         if (x[3] <= 0.10571999847888947) {
#                                             votes[0] += 1;
#                                         }
#
#                                         else {
#                                             votes[0] += 1;
#                                         }
#                                     }
#
#                                     else {
#                                         if (x[3] <= 0.044015999883413315) {
#                                             votes[0] += 1;
#                                         }
#
#                                         else {
#                                             votes[3] += 1;
#                                         }
#                                     }
#                                 }
#
#                                 else {
#                                     if (x[0] <= 0.33883702754974365) {
#                                         if (x[2] <= 0.04550769180059433) {
#                                             votes[0] += 1;
#                                         }
#
#                                         else {
#                                             votes[3] += 1;
#                                         }
#                                     }
#
#                                     else {
#                                         if (x[3] <= 0.030791998840868473) {
#                                             votes[3] += 1;
#                                         }
#
#                                         else {
#                                             votes[3] += 1;
#                                         }
#                                     }
#                                 }
#                             }
#
#                             else {
#                                 if (x[1] <= 0.08094475418329239) {
#                                     if (x[3] <= 0.0926160030066967) {
#                                         if (x[1] <= 0.045920128002762794) {
#                                             votes[0] += 1;
#                                         }
#
#                                         else {
#                                             votes[0] += 1;
#                                         }
#                                     }
#
#                                     else {
#                                         if (x[2] <= 0.15495384484529495) {
#                                             votes[3] += 1;
#                                         }
#
#                                         else {
#                                             votes[0] += 1;
#                                         }
#                                     }
#                                 }
#
#                                 else {
#                                     if (x[0] <= 0.3342224955558777) {
#                                         if (x[3] <= 0.04391999915242195) {
#                                             votes[0] += 1;
#                                         }
#
#                                         else {
#                                             votes[3] += 1;
#                                         }
#                                     }
#
#                                     else {
#                                         if (x[3] <= 0.023976000025868416) {
#                                             votes[3] += 1;
#                                         }
#
#                                         else {
#                                             votes[3] += 1;
#                                         }
#                                     }
#                                 }
#                             }
#                         }
#
#                         // tree #6
#                         if (x[1] <= 0.11974360048770905) {
#                             if (x[2] <= 0.10498461499810219) {
#                                 if (x[0] <= 0.18924500793218613) {
#                                     if (x[1] <= 0.0017398870550096035) {
#                                         votes[1] += 1;
#                                     }
#
#                                     else {
#                                         if (x[0] <= 0.03248112089931965) {
#                                             votes[1] += 1;
#                                         }
#
#                                         else {
#                                             votes[2] += 1;
#                                         }
#                                     }
#                                 }
#
#                                 else {
#                                     if (x[1] <= 0.021557383239269257) {
#                                         if (x[0] <= 0.2688092291355133) {
#                                             votes[2] += 1;
#                                         }
#
#                                         else {
#                                             votes[0] += 1;
#                                         }
#                                     }
#
#                                     else {
#                                         if (x[3] <= 0.11090400069952011) {
#                                             votes[0] += 1;
#                                         }
#
#                                         else {
#                                             votes[3] += 1;
#                                         }
#                                     }
#                                 }
#                             }
#
#                             else {
#                                 if (x[0] <= 0.13096874207258224) {
#                                     if (x[2] <= 0.11113846302032471) {
#                                         if (x[1] <= 0.03978135250508785) {
#                                             votes[1] += 1;
#                                         }
#
#                                         else {
#                                             votes[0] += 1;
#                                         }
#                                     }
#
#                                     else {
#                                         if (x[0] <= 0.08124987408518791) {
#                                             votes[2] += 1;
#                                         }
#
#                                         else {
#                                             votes[2] += 1;
#                                         }
#                                     }
#                                 }
#
#                                 else {
#                                     if (x[0] <= 0.3647025376558304) {
#                                         if (x[3] <= 0.02145600039511919) {
#                                             votes[0] += 1;
#                                         }
#
#                                         else {
#                                             votes[0] += 1;
#                                         }
#                                     }
#
#                                     else {
#                                         if (x[1] <= 0.05203632637858391) {
#                                             votes[0] += 1;
#                                         }
#
#                                         else {
#                                             votes[3] += 1;
#                                         }
#                                     }
#                                 }
#                             }
#                         }
#
#                         else {
#                             if (x[0] <= 0.2883284389972687) {
#                                 if (x[0] <= 0.058373671025037766) {
#                                     if (x[1] <= 0.20317427814006805) {
#                                         if (x[3] <= 0.09386400133371353) {
#                                             votes[2] += 1;
#                                         }
#
#                                         else {
#                                             votes[2] += 1;
#                                         }
#                                     }
#
#                                     else {
#                                         if (x[0] <= 0.03380599990487099) {
#                                             votes[2] += 1;
#                                         }
#
#                                         else {
#                                             votes[0] += 1;
#                                         }
#                                     }
#                                 }
#
#                                 else {
#                                     if (x[0] <= 0.13147691637277603) {
#                                         if (x[2] <= 0.08381538465619087) {
#                                             votes[2] += 1;
#                                         }
#
#                                         else {
#                                             votes[0] += 1;
#                                         }
#                                     }
#
#                                     else {
#                                         if (x[0] <= 0.2598138898611069) {
#                                             votes[0] += 1;
#                                         }
#
#                                         else {
#                                             votes[0] += 1;
#                                         }
#                                     }
#                                 }
#                             }
#
#                             else {
#                                 if (x[2] <= 0.044523077085614204) {
#                                     if (x[1] <= 0.1940046101808548) {
#                                         if (x[0] <= 0.407815158367157) {
#                                             votes[0] += 1;
#                                         }
#
#                                         else {
#                                             votes[3] += 1;
#                                         }
#                                     }
#
#                                     else {
#                                         if (x[2] <= 0.03904615342617035) {
#                                             votes[3] += 1;
#                                         }
#
#                                         else {
#                                             votes[0] += 1;
#                                         }
#                                     }
#                                 }
#
#                                 else {
#                                     if (x[0] <= 0.3627443164587021) {
#                                         if (x[2] <= 0.08172307908535004) {
#                                             votes[3] += 1;
#                                         }
#
#                                         else {
#                                             votes[3] += 1;
#                                         }
#                                     }
#
#                                     else {
#                                         votes[3] += 1;
#                                     }
#                                 }
#                             }
#                         }
#
#                         // tree #7
#                         if (x[1] <= 0.10896264389157295) {
#                             if (x[0] <= 0.198160320520401) {
#                                 if (x[0] <= 0.12078917399048805) {
#                                     if (x[0] <= 0.027858479879796505) {
#                                         if (x[3] <= 0.08462399989366531) {
#                                             votes[1] += 1;
#                                         }
#
#                                         else {
#                                             votes[2] += 1;
#                                         }
#                                     }
#
#                                     else {
#                                         if (x[3] <= 0.04017600044608116) {
#                                             votes[2] += 1;
#                                         }
#
#                                         else {
#                                             votes[2] += 1;
#                                         }
#                                     }
#                                 }
#
#                                 else {
#                                     if (x[2] <= 0.08726153522729874) {
#                                         if (x[3] <= 0.08824799954891205) {
#                                             votes[2] += 1;
#                                         }
#
#                                         else {
# ...
#                                         }
#
#                                         else {
#                                             votes[2] += 1;
#                                         }
#                                     }
#
#                                     else {
#                                         if (x[1] <= 0.19816266000270844) {
#                                             votes[2] += 1;
#                                         }
#
#                                         else {
#                                             votes[0] += 1;
#                                         }
#                                     }
#                                 }
#
#                                 else {
#                                     if (x[1] <= 0.14301329851150513) {
#                                         if (x[2] <= 0.1191076934337616) {
#                                             votes[2] += 1;
#                                         }
#
#                                         else {
#                                             votes[2] += 1;
#                                         }
#                                     }
#
#                                     else {
#                                         if (x[2] <= 0.08052307739853859) {
#                                             votes[2] += 1;
#                                         }
#
#                                         else {
#                                             votes[0] += 1;
#                                         }
#                                     }
#                                 }
#                             }
#
#                             else {
#                                 if (x[2] <= 0.0461230780929327) {
#                                     if (x[0] <= 0.19741211086511612) {
#                                         if (x[3] <= 0.004704000079073012) {
#                                             votes[1] += 1;
#                                         }
#
#                                         else {
#                                             votes[2] += 1;
#                                         }
#                                     }
#
#                                     else {
#                                         if (x[0] <= 0.2871452420949936) {
#                                             votes[0] += 1;
#                                         }
#
#                                         else {
#                                             votes[2] += 1;
#                                         }
#                                     }
#                                 }
#
#                                 else {
#                                     if (x[1] <= 0.045851126313209534) {
#                                         if (x[0] <= 0.20623807609081268) {
#                                             votes[2] += 1;
#                                         }
#
#                                         else {
#                                             votes[0] += 1;
#                                         }
#                                     }
#
#                                     else {
#                                         if (x[1] <= 0.22122354805469513) {
#                                             votes[0] += 1;
#                                         }
#
#                                         else {
#                                             votes[0] += 1;
#                                         }
#                                     }
#                                 }
#                             }
#                         }
#
#                         else {
#                             if (x[2] <= 0.08366153761744499) {
#                                 if (x[0] <= 0.42049242556095123) {
#                                     if (x[1] <= 0.1434919834136963) {
#                                         if (x[0] <= 0.3984505236148834) {
#                                             votes[0] += 1;
#                                         }
#
#                                         else {
#                                             votes[0] += 1;
#                                         }
#                                     }
#
#                                     else {
#                                         if (x[0] <= 0.31472572684288025) {
#                                             votes[0] += 1;
#                                         }
#
#                                         else {
#                                             votes[3] += 1;
#                                         }
#                                     }
#                                 }
#
#                                 else {
#                                     if (x[1] <= 0.10813998058438301) {
#                                         if (x[3] <= 0.04619999974966049) {
#                                             votes[0] += 1;
#                                         }
#
#                                         else {
#                                             votes[0] += 1;
#                                         }
#                                     }
#
#                                     else {
#                                         if (x[1] <= 0.1373080164194107) {
#                                             votes[3] += 1;
#                                         }
#
#                                         else {
#                                             votes[3] += 1;
#                                         }
#                                     }
#                                 }
#                             }
#
#                             else {
#                                 if (x[1] <= 0.08903036639094353) {
#                                     if (x[0] <= 0.41982027888298035) {
#                                         if (x[3] <= 0.0833280012011528) {
#                                             votes[0] += 1;
#                                         }
#
#                                         else {
#                                             votes[3] += 1;
#                                         }
#                                     }
#
#                                     else {
#                                         if (x[1] <= 0.042361149564385414) {
#                                             votes[3] += 1;
#                                         }
#
#                                         else {
#                                             votes[3] += 1;
#                                         }
#                                     }
#                                 }
#
#                                 else {
#                                     if (x[0] <= 0.3025786578655243) {
#                                         if (x[1] <= 0.13368170708417892) {
#                                             votes[0] += 1;
#                                         }
#
#                                         else {
#                                             votes[3] += 1;
#                                         }
#                                     }
#
#                                     else {
#                                         if (x[0] <= 0.3231023848056793) {
#                                             votes[3] += 1;
#                                         }
#
#                                         else {
#                                             votes[3] += 1;
#                                         }
#                                     }
#                                 }
#                             }
#                         }
#
#                         // tree #100
#                         if (x[1] <= 0.11874924972653389) {
#                             if (x[0] <= 0.1627085655927658) {
#                                 if (x[3] <= 0.04017600044608116) {
#                                     if (x[0] <= 0.034142861142754555) {
#                                         if (x[2] <= 0.11424615234136581) {
#                                             votes[1] += 1;
#                                         }
#
#                                         else {
#                                             votes[1] += 1;
#                                         }
#                                     }
#
#                                     else {
#                                         if (x[0] <= 0.06274123676121235) {
#                                             votes[2] += 1;
#                                         }
#
#                                         else {
#                                             votes[2] += 1;
#                                         }
#                                     }
#                                 }
#
#                                 else {
#                                     if (x[0] <= 0.12068259716033936) {
#                                         if (x[1] <= 0.019936220720410347) {
#                                             votes[2] += 1;
#                                         }
#
#                                         else {
#                                             votes[2] += 1;
#                                         }
#                                     }
#
#                                     else {
#                                         if (x[0] <= 0.1215510293841362) {
#                                             votes[0] += 1;
#                                         }
#
#                                         else {
#                                             votes[0] += 1;
#                                         }
#                                     }
#                                 }
#                             }
#
#                             else {
#                                 if (x[0] <= 0.39970317482948303) {
#                                     if (x[0] <= 0.22747644037008286) {
#                                         if (x[1] <= 0.044826989993453026) {
#                                             votes[2] += 1;
#                                         }
#
#                                         else {
#                                             votes[0] += 1;
#                                         }
#                                     }
#
#                                     else {
#                                         if (x[0] <= 0.38048161566257477) {
#                                             votes[0] += 1;
#                                         }
#
#                                         else {
#                                             votes[0] += 1;
#                                         }
#                                     }
#                                 }
#
#                                 else {
#                                     if (x[2] <= 0.09879999980330467) {
#                                         if (x[3] <= 0.06652799993753433) {
#                                             votes[0] += 1;
#                                         }
#
#                                         else {
#                                             votes[3] += 1;
#                                         }
#                                     }
#
#                                     else {
#                                         if (x[3] <= 0.025031999684870243) {
#                                             votes[0] += 1;
#                                         }
#
#                                         else {
#                                             votes[3] += 1;
#                                         }
#                                     }
#                                 }
#                             }
#                         }
#
#                         else {
#                             if (x[3] <= 0.047016000375151634) {
#                                 if (x[0] <= 0.35089580714702606) {
#                                     if (x[3] <= 0.03100800048559904) {
#                                         if (x[2] <= 0.09972307831048965) {
#                                             votes[0] += 1;
#                                         }
#
#                                         else {
#                                             votes[0] += 1;
#                                         }
#                                     }
#
#                                     else {
#                                         if (x[2] <= 0.08618461713194847) {
#                                             votes[2] += 1;
#                                         }
#
#                                         else {
#                                             votes[0] += 1;
#                                         }
#                                     }
#                                 }
#
#                                 else {
#                                     if (x[1] <= 0.1578318253159523) {
#                                         if (x[0] <= 0.41825905442237854) {
#                                             votes[0] += 1;
#                                         }
#
#                                         else {
#                                             votes[3] += 1;
#                                         }
#                                     }
#
#                                     else {
#                                         if (x[2] <= 0.0056615384528413415) {
#                                             votes[0] += 1;
#                                         }
#
#                                         else {
#                                             votes[3] += 1;
#                                         }
#                                     }
#                                 }
#                             }
#
#                             else {
#                                 if (x[2] <= 0.07766153663396835) {
#                                     if (x[3] <= 0.09213599935173988) {
#                                         if (x[0] <= 0.32203370332717896) {
#                                             votes[0] += 1;
#                                         }
#
#                                         else {
#                                             votes[3] += 1;
#                                         }
#                                     }
#
#                                     else {
#                                         if (x[2] <= 0.0050769231747835875) {
#                                             votes[2] += 1;
#                                         }
#
#                                         else {
#                                             votes[3] += 1;
#                                         }
#                                     }
#                                 }
#
#                                 else {
#                                     if (x[0] <= 0.23846547305583954) {
#                                         if (x[0] <= 0.025521360337734222) {
#                                             votes[0] += 1;
#                                         }
#
#                                         else {
#                                             votes[0] += 1;
#                                         }
#                                     }
#
#                                     else {
#                                         if (x[0] <= 0.30929704010486603) {
#                                             votes[3] += 1;
#                                         }
#
#                                         else {
#                                             votes[3] += 1;
#                                         }
#                                     }
#                                 }
#                             }
#                         }
#
#                         // return argmax of votes
#                         uint8_t classIdx = 0;
#                         float maxVotes = votes[0];
#
#                         for (uint8_t i = 1; i < 4; i++) {
#                             if (votes[i] > maxVotes) {
#                                 classIdx = i;
#                                 maxVotes = votes[i];
#                             }
#                         }
#
#                         return classIdx;
#                     }
#
#                 protected:
#                 };
#             }
#         }
#     }

# %%
# Visualizar los primeros tres árboles del bosque
fig, axes = plt.subplots(nrows = 1,ncols = 2,figsize = (30,10), dpi=100)
for index in range(0, 2):
    tree.plot_tree(bosque_varroa.estimators_[index],
                   feature_names=list(X.columns.values),
                   class_names=list(Y.values),
                   filled=True,
                   ax = axes[index])
plt.show()

# %%
Y_pred = bosque_varroa.predict(X_test)

Y_pred
# Out:
# array(['Medio', 'Muy Alto', 'Muy Alto', ..., 'Alto', 'Medio', 'Medio'],
#       dtype=object)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
matriz = confusion_matrix(Y_test, Y_pred)
matriz
# Out:
# array([[3677,    0,   95,   87],
#        [   0,   11,  172,    0],
#        [ 376,    0, 1577,    0],
#        [ 302,    0,    0, 1703]])

# %%
# Etiquetas de las clases
class_names = ['Alto', 'Bajo', 'Medio', 'Muy Alto']

# Graficar la matriz de confusión
plt.figure(figsize=(8, 6))
sns.heatmap(matriz, annot=True, fmt='d', cmap='Blues', cbar=False,
            xticklabels=class_names, yticklabels=class_names)

plt.xlabel('Predicciones')
plt.ylabel('Etiquetas reales')
plt.title('Matriz de Confusión')
plt.show()

# %%
# Calcular la exactitud (Accuracy)
accuracy = accuracy_score(Y_test, Y_pred)
print(f"Exactitud (Accuracy): {accuracy}")

# Reporte de Clasificación (precision, recall, f1-score)
reporte_clasificacion = classification_report(Y_test, Y_pred)
print("Reporte de Clasificación:")
print(reporte_clasificacion)

matriz
# Out:
# Exactitud (Accuracy): 0.871
# Reporte de Clasificación:
#               precision    recall  f1-score   support
#
#         Alto       0.84      0.95      0.90      3859
#         Bajo       1.00      0.06      0.11       183
#        Medio       0.86      0.81      0.83      1953
#     Muy Alto       0.95      0.85      0.90      2005
#
#     accuracy                           0.87      8000
#    macro avg       0.91      0.67      0.68      8000
# weighted avg       0.88      0.87      0.86      8000
# array([[3677,    0,   95,   87],
#        [   0,   11,  172,    0],
#        [ 376,    0, 1577,    0],
#        [ 302,    0,    0, 1703]])
